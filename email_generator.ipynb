# %%
# !pip install langchain_groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature = 0,
    groq_api_key = "GROQ_API_KEY",
    model_name = "llama3-8b-8192"
)
response = llm.invoke("The first person to land on moon was...")
print(response.content)

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.4 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://careers.nike.com/software-engineer-i-itc/job/R-65382")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Software Engineer I, ITC
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# Converse Careers
#
#
#
#
#
#
#
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
    """
    ### SCRAPED TEXT FROM WEBSITE:
    {page_data}
    The scraped text is from career's page of a webiste.
    Your job is to extract the job postings and return them in JSON format containing the
    following keys: `role`,`experience`,`skills` and `description`.
    Only return the valid JSON.
    ### VALID JSON (NO PREAMBLE):
    """
)

chain_extract = prompt_extract | llm
res = chain_extract.invoke(input={'page_data':page_data})
print(res.content)
type(res.content)
# Out:
# Here is the extracted job posting in JSON format:
#
# ```
# [
#   {
#     "role": "Software Engineer I, ITC",
#     "experience": "0-2 years of hands-on experience as a Software Engineer",
#     "skills": [
#       "Evangelize and cultivate adoption of GPaaS, open source software and agile principles within the organization",
#       "Ensure solutions are designed and developed using a scalable, highly resilient cloud native architecture",
#       "Deliver well-documented and well-tested code, and participate in peer code reviews",
#       "Design and develop tools and frameworks to improve security, reliability, maintainability, availability and performance for the technology foundation of our platform"
#     ],
# ...

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'Software Engineer I, ITC',
#   'experience': '0-2 years of hands-on experience as a Software Engineer',
#   'skills': ['Evangelize and cultivate adoption of GPaaS, open source software and agile principles within the organization',
#    'Ensure solutions are designed and developed using a scalable, highly resilient cloud native architecture',
#    'Deliver well-documented and well-tested code, and participate in peer code reviews',
#    'Design and develop tools and frameworks to improve security, reliability, maintainability, availability and performance for the technology foundation of our platform'],
# ...

# %%
type(json_res)
# Out:
# list

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
# !pip install onnxruntime

# %%
# !pip install chromadb

# %%
import chromadb

# %%
chromadb.__version__
# Out:
# '1.0.15'

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids= [str(uuid.uuid4())])

# %%
links = collection.query(query_texts=["skills"], n_results=2).get('metadatas',[])
links
# Out:
# [[{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}]]

# %%
job = json_res
job_skills = job[0]['skills']
print(job_skills)
# Out:
# ['Evangelize and cultivate adoption of GPaaS, open source software and agile principles within the organization', 'Ensure solutions are designed and developed using a scalable, highly resilient cloud native architecture', 'Deliver well-documented and well-tested code, and participate in peer code reviews', 'Design and develop tools and frameworks to improve security, reliability, maintainability, availability and performance for the technology foundation of our platform']

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}

        ### INSTRUCTION:
        You are Monaa, a business development executive at Manav Enterprise. Manav Enterprise is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools.
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability,
        process optimization, cost reduction, and heightened overall efficiency.
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of Manav Enterprise
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Manav Enterprise's portfolio: {link_list}
        Remember you are Monaa, BDE at Manav Enterprise.
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):

        """
        )

# %%
chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Unlocking Nike's Next-Generation Platforms with Manav Enterprise
#
# Dear [Hiring Manager],
#
# I came across the job description for a Software Engineer I, ITC at Nike, and I was impressed by the exciting opportunity to shape and deliver next-generation platforms. As a business development executive at Manav Enterprise, I'd like to introduce our company's capabilities in fulfilling your needs.
#
# At Manav Enterprise, we specialize in AI & Software Consulting, empowering enterprises with tailored solutions for scalability, process optimization, cost reduction, and heightened efficiency. Our team of experts has a proven track record in delivering high-quality solutions, and I'd like to highlight some of our relevant portfolio projects:
#
# * [Link: https://example.com/ml-python-portfolio] - Our machine learning and Python portfolio showcases our expertise in building scalable and resilient solutions.
# ...
